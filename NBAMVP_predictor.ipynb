# %%
import pandas as pd

# %%
stats = pd.read_csv("PlayerMVPStats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14692       14692   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14693       14693     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14694       14694  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14695       14695      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14696       14696      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
#        Pts Max  Share                Team     W     L   W/L%   GB   PS/G  \
# 0          0.0    0.0  Los Angeles Lakers  58.0  24.0  0.707  5.0  106.3
# 1          0.0    0.0  Los Angeles Lakers  58.0  24.0  0.707  5.0  106.3
# 2          0.0    0.0  Los Angeles Lakers  58.0  24.0  0.707  5.0  106.3
# 3          0.0    0.0  Los Angeles Lakers  58.0  24.0  0.707  5.0  106.3
# 4          0.0    0.0  Los Angeles Lakers  58.0  24.0  0.707  5.0  106.3
# ...        ...    ...                 ...   ...   ...    ...  ...    ...
# 14692      0.0    0.0     Milwaukee Bucks  42.0  40.0  0.512  9.0  103.6
# 14693      0.0    0.0     Milwaukee Bucks  42.0  40.0  0.512  9.0  103.6
# 14694      0.0    0.0     Milwaukee Bucks  42.0  40.0  0.512  9.0  103.6
# 14695      0.0    0.0     Milwaukee Bucks  42.0  40.0  0.512  9.0  103.6
# 14696      0.0    0.0     Milwaukee Bucks  42.0  40.0  0.512  9.0  103.6
#
#         PA/G   SRS
# 0       99.6  6.73
# 1       99.6  6.73
# 2       99.6  6.73
# 3       99.6  6.73
# 4       99.6  6.73
# ...      ...   ...
# 14692  103.8 -0.45
# 14693  103.8 -0.45
# 14694  103.8 -0.45
# 14695  103.8 -0.45
# 14696  103.8 -0.45
#
# [14697 rows x 42 columns]

# %% [markdown]
# In order to work with this data set, I cleaned up the csv file and deleted any unnecessary columns. I also replaced all the NA values with 0s.

# %%
del stats["Unnamed: 0"]

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          59
# 3P            0
# 3PA           0
# 3P%        2086
# 2P            0
# 2PA           0
# 2P%         100
# eFG%         59
# FT            0
# FTA           0
# FT%         521
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W           288
# L           288
# W/L%        288
# GB          288
# PS/G        288
# PA/G        288
# SRS         288
# dtype: int64

# %%
stats = stats.fillna(0)

# %% [markdown]
# Now, by looking through all possible columns, I wanted to see which columns I could use as my predictors in order to predict the "Share" column.

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = [ 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 
        'W', 'L', 'W/L%', 'GB', 'PS/G','PA/G', 'SRS']

# %% [markdown]
# I chose all columns that had numerical values and weren't directly correlated to the "Share" column. The "Pts Won" and "Pts Max" are columns directly correlated and would only make the model less accurate.
#
# Now I decided to play around with the model to see if my 2022 MVP prediction would be accurate.

# %%
train = stats[stats["Year"] < 2022]

# %%
test = stats[stats["Year"] == 2022]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha = .1)

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
predictions = pd.DataFrame(predictions, columns = ["predictions"], index = test.index)

# %%
predictions
# Out:
#        predictions
# 648       0.012934
# 649      -0.028142
# 650      -0.006163
# 651       0.016564
# 652      -0.004820
# ...            ...
# 12508     0.060355
# 12509     0.069539
# 12510     0.083546
# 12511     0.080897
# 12512     0.022729
#
# [605 rows x 1 columns]

# %%
combination = pd.concat([test[["Player","Share"]],predictions],axis=1)

# %% [markdown]
# I was able to see how my regressive predictor ranked individuals in the 2022 season, by how many votes they would recieve. The highest value indicates that they would have won MVP.

# %%
combination
# Out:
#                 Player  Share  predictions
# 648       Aaron Gordon    0.0     0.012934
# 649      Austin Rivers    0.0    -0.028142
# 650            Bol Bol    0.0    -0.006163
# 651       Bones Hyland    0.0     0.016564
# 652        Bryn Forbes    0.0    -0.004820
# ...                ...    ...          ...
# 12508     Micah Potter    0.0     0.060355
# 12509  Rodney McGruder    0.0     0.069539
# 12510        Saben Lee    0.0     0.083546
# 12511       Saddiq Bey    0.0     0.080897
# 12512   Trayvon Palmer    0.0     0.022729
#
# [605 rows x 3 columns]

# %%
combination.sort_values("Share", ascending=False).head(10)
# Out:
#                       Player  Share  predictions
# 663             Nikola Jokić  0.875     0.190365
# 837              Joel Embiid  0.706     0.190462
# 11678  Giannis Antetokounmpo  0.595     0.219410
# 907             Devin Booker  0.216     0.091309
# 11469            Luka Dončić  0.146     0.157395
# 1179            Jayson Tatum  0.043     0.095902
# 12226              Ja Morant  0.010     0.120508
# 6398           Stephen Curry  0.004     0.093138
# 905               Chris Paul  0.002     0.078329
# 8241            LeBron James  0.001     0.236135

# %% [markdown]
# The model was not accurate in showing the 2022 MVP, when compared to the "Share" column for the season, we can see that my model predicted Giannis Antetokunmpo to be the MVP, instead Nikola Jokic was the MVP.
#
# I then went forward in determining an error metric to see how accurate my predictor could be for all seasons in the data set.

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(combination["Share"],combination["predictions"])
# Out:
# 0.0052267057271756096

# %% [markdown]
# Using the mean squared error object from sklearn, I was not able to generat an accurate error metric, since the data set has many rows of people who recieved No votes. The mean squared error from sklearn would not be useful for this model. Therefore I would have to create my own way of determining how accurate the model was.

# %%
combination["Share"].value_counts()
# Out:
# 0.000    593
# 0.001      3
# 0.875      1
# 0.706      1
# 0.002      1
# 0.216      1
# 0.043      1
# 0.004      1
# 0.146      1
# 0.595      1
# 0.010      1
# Name: Share, dtype: int64

# %%
combination = combination.sort_values("Share", ascending= False)
combination["Rk"] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions  Rk
# 663             Nikola Jokić  0.875     0.190365   1
# 837              Joel Embiid  0.706     0.190462   2
# 11678  Giannis Antetokounmpo  0.595     0.219410   3
# 907             Devin Booker  0.216     0.091309   4
# 11469            Luka Dončić  0.146     0.157395   5
# 1179            Jayson Tatum  0.043     0.095902   6
# 12226              Ja Morant  0.010     0.120508   7
# 6398           Stephen Curry  0.004     0.093138   8
# 905               Chris Paul  0.002     0.078329   9
# 8241            LeBron James  0.001     0.236135  10

# %%
combination = combination.sort_values("predictions", ascending =False)
combination["Prediction_Rk"] = list(range(1,combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                         Player  Share  predictions   Rk  Prediction_Rk
# 8241              LeBron James  0.001     0.236135   10              1
# 11678    Giannis Antetokounmpo  0.595     0.219410    3              2
# 837                Joel Embiid  0.706     0.190462    2              3
# 663               Nikola Jokić  0.875     0.190365    1              4
# 8231             Anthony Davis  0.000     0.185613  112              5
# 8582           Dejounte Murray  0.000     0.173725   84              6
# 1211   Shai Gilgeous-Alexander  0.000     0.166799  313              7
# 5031            Christian Wood  0.000     0.158033  479              8
# 11469              Luka Dončić  0.146     0.157395    5              9
# 1856          Domantas Sabonis  0.000     0.154263  344             10

# %%
combination.sort_values("Share", ascending = False).head(10)
# Out:
#                       Player  Share  predictions  Rk  Prediction_Rk
# 663             Nikola Jokić  0.875     0.190365   1              4
# 837              Joel Embiid  0.706     0.190462   2              3
# 11678  Giannis Antetokounmpo  0.595     0.219410   3              2
# 907             Devin Booker  0.216     0.091309   4             79
# 11469            Luka Dončić  0.146     0.157395   5              9
# 1179            Jayson Tatum  0.043     0.095902   6             64
# 12226              Ja Morant  0.010     0.120508   7             28
# 6398           Stephen Curry  0.004     0.093138   8             73
# 905               Chris Paul  0.002     0.078329   9            142
# 3938           DeMar DeRozan  0.001     0.099241  11             54

# %% [markdown]
# The first step in creating an error metric was to first rank each player, first by their rank based on the "Share" column, and then another rank by the "predictions" column. When I compared these columns together, I was able to find a metric more suitable for my model.

# %%
def find_ap(combination):
    actual = combination.sort_values("Share", ascending = False).head(5)
    predicted = combination.sort_values("predictions", ascending =False)
    ps =[]
    found = 0
    seen = 1
    for index, row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found +=1
            ps.append(found/seen)
        seen += 1
    return sum(ps)/len(ps)

# %% [markdown]
# I created this function to find the average precision (ap), by using the top 5 players in the actual rank column and comparing them to the top 5 players int he predicted rank column. I only used the top 5 players since these would typically be the players with the most votes anyway, disregarding all players with 0 votes completely.

# %%
find_ap(combination)
# Out:
# 0.4848804500703234

# %% [markdown]
# when we run the function, we can see that my modelw as only 48% accurate as of now.
#
# Next I decided to run the model using the first 5 years in the data set (1991-1995) to train the model and the rest of the years to be tested on.

# %%
years = list(range(1991,2023))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns = ["predictions"], index = test.index)
    combination = pd.concat([test[["Player","Share"]],predictions],axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps)/ len(aps)
# Out:
# 0.7029029551156751

# %% [markdown]
# Here, on average, the model was 70% in predicting the ranks of the top 5 players for the MVP vote after 1995.
#
# I decided to create funtions to streamline adding ranks and running the find_ap function for every year, rather than continuosely using the for loop from above.
#
# The add_ranks function adds the ranks per year, and the the backtest function runs the for loop for every year, while adding the ranks and finding the average precision per iteration.

# %%
def add_ranks(combination):
    combination = combination.sort_values("Share", ascending= False)
    combination["Rk"] = list(range(1,combination.shape[0]+1))
    combination = combination.sort_values("predictions", ascending =False)
    combination["Prediction_Rk"] = list(range(1,combination.shape[0]+1))
    combination["Diff"] = combination["Rk"] - combination["Prediction_Rk"]
    return combination

# %%
ranking = add_ranks(all_predictions[1])
ranking[ranking["Rk"] < 6].sort_values("Diff",ascending = False)
# Out:
#                Player  Share  predictions  Rk  Prediction_Rk  Diff
# 1710      Karl Malone  0.857     0.192318   1              2    -1
# 10976  Michael Jordan  0.832     0.167629   2              3    -1
# 970        Grant Hill  0.327     0.128646   3              6    -3
# 4912     Tim Hardaway  0.207     0.059984   4             20   -16
# 8642        Glen Rice  0.117     0.033110   5             53   -48

# %%
def backtest(stats, model, year, predictors):
    aps = []
    all_predictions = []
    for year in years[5:]:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = reg.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns = ["predictions"], index = test.index)
        combination = pd.concat([test[["Player","Share"]],predictions],axis=1)
        combination = add_ranks(combination)
        combination["Year"] = stats["Year"]
        combination["PTS"] = stats["PTS"]
        combination["AST"] = stats["AST"]
        combination["TRB"] = stats["TRB"]
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps)/len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats,reg,years[5:],predictors)

# %%
mean_ap
# Out:
# 0.7029029551156751

# %% [markdown]
# Here, the backtest function showed the same ap as the for loop above. This means that we can start adding predictors and playing around with the models to gain a higher mean_ap value, without having to hard code our for loop every time.

# %%
all_predictions[all_predictions["Rk"] < 6].sort_values("Diff").head(10)
# Out:
#                  Player  Share  predictions  Rk  Prediction_Rk  Diff  Year  \
# 907        Devin Booker  0.216     0.091309   4             79   -75  2022
# 1334         Jason Kidd  0.712     0.028210   2             52   -50  2002
# 8642          Glen Rice  0.117     0.033110   5             53   -48  1997
# 5420         Steve Nash  0.839     0.034100   1             45   -44  2005
# 8910    Peja Stojaković  0.228     0.036270   4             38   -34  2004
# 13331       Joakim Noah  0.258     0.046968   4             37   -33  2014
# 5438         Steve Nash  0.739     0.054129   1             34   -33  2006
# 3849   Chauncey Billups  0.344     0.052696   5             35   -30  2006
# 1499         Chris Paul  0.138     0.072293   5             33   -28  2021
# 5453         Steve Nash  0.785     0.074421   2             21   -19  2007
#
#         PTS   AST   TRB
# 907    26.8   4.8   5.0
# 1334   14.7   9.9   7.3
# 8642   26.8   2.0   4.0
# 5420   15.5  11.5   3.3
# 8910   24.2   2.1   6.3
# 13331  12.6   5.4  11.3
# 5438   18.8  10.5   4.2
# 3849   18.5   8.6   3.1
# 1499   16.4   8.9   4.5
# 5453   18.6  11.6   3.5

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)],axis =1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.087852  eFG%
# 18  0.033860   DRB
# 29  0.023198  W/L%
# 17  0.020993   ORB
# 10  0.016456    2P
# 21  0.012070   STL
# 22  0.010901   BLK
# 15  0.010414   FTA
# 20  0.007113   AST
# 12  0.007054   2P%
# 25  0.006918   PTS
# 5   0.004827   FGA
# 4   0.003353    FG
# 7   0.001701    3P
# 0   0.000294   Age
# 30  0.000279    GB
# 27  0.000136     W
# 1   0.000093     G
# 2   0.000004    GS
# 26 -0.000180  Year
# 32 -0.000275  PA/G
# 28 -0.000316     L
# 31 -0.000494  PS/G
# 33 -0.000569   SRS
# 24 -0.002625    PF
# 3  -0.004067    MP
# 16 -0.004784   FT%
# 14 -0.006344    FT
# 23 -0.009142   TOV
# 8  -0.009681   3PA
# 9  -0.009695   3P%
# 11 -0.016464   2PA
# 19 -0.026578   TRB
# 6  -0.155936   FG%

# %% [markdown]
# By grabing the coefficients, we can see which columns have the most emphasis in the model. I decided to compare the PTS, AST, STL, BLK, 3P, Year, eFG%, W/L%, and TRB columns and create a new column that shows how each player performed in these categories as a ratio of the average in that stat line.

# %%
stats_ratios = stats[["PTS","AST","STL","BLK","3P","Year","eFG%","W/L%","TRB"]].groupby("Year").apply(lambda x: (x)/x.mean())

# %%
stats_ratios
# Out:
#             PTS       AST       STL       BLK        3P  Year      eFG%  \
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0  1.041653
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0  1.093092
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0  0.975210
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0  0.728728
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0  1.073803
# ...         ...       ...       ...       ...       ...   ...       ...
# 14692  0.735752  0.819562  0.479763  1.528302  0.650951   1.0  1.074210
# 14693  0.071202  0.000000  0.000000  0.000000  0.130190   1.0  0.724940
# 14694  1.281633  0.601012  1.119447  2.547170  0.520761   1.0  0.992985
# 14695  0.474679  0.218550  0.319842  1.273585  0.650951   1.0  1.088425
# 14696  1.008693  0.655649  1.119447  0.509434  2.343424   1.0  1.194018
#
#            W/L%       TRB
# 0      1.438663  1.706296
# 1      1.438663  0.812522
# 2      1.438663  0.487513
# 3      1.438663  0.325009
# 4      1.438663  1.245867
# ...         ...       ...
# 14692  1.029491  0.981705
# 14693  1.029491  0.112195
# 14694  1.029491  1.598776
# 14695  1.029491  0.560974
# 14696  1.029491  0.869510
#
# [14697 rows x 9 columns]

# %%
stats[["PTS_T","AST_R","STL_R","BLK_R","3P_R","eFG%_R","W/L%_R","TRB_R"]] = stats_ratios[["PTS","AST","STL","BLK","3P","eFG%","W/L%","TRB"]]

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  PA/G  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  99.6
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  99.6
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  99.6
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  99.6
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  99.6
#
#     SRS     PTS_T     AST_R     STL_R     BLK_R      3P_R    eFG%_R    W/L%_R  \
# 0  6.73  1.013334  0.420714  0.961127  0.673469  0.508587  1.041653  1.438663
# 1  6.73  1.614653  1.028412  1.647646  0.673469  4.577279  1.093092  1.438663
# 2  6.73  0.311795  0.093492  0.274608  1.571429  0.000000  0.975210  1.438663
# 3  6.73  0.200440  0.186984  0.274608  0.000000  0.000000  0.728728  1.438663
# 4  6.73  2.383005  1.636110  1.784950  0.897959  1.525760  1.073803  1.438663
#
#       TRB_R
# 0  1.706296
# 1  0.812522
# 2  0.487513
# 3  0.325009
# 4  1.245867
#
# [5 rows x 49 columns]

# %%
predictors += ["PTS_T","AST_R","STL_R","BLK_R","3P_R","eFG%_R","W/L%_R","TRB_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats,reg,years[5:],predictors)

# %%
mean_ap
# Out:
# 0.7219067662808563

# %% [markdown]
# By doing this, our model increased by 2% precision compared to origninally, which is alot in a model that has so many depended varaibles.

# %%
stats["NPos"] = stats["Pos"].astype("category").cat.codes

# %%
stats["Ntm"] = stats["Tm"].astype("category").cat.codes

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 1, min_samples_split =5)

# %%
mean_ap, aps, all_predictions = backtest(stats,rf,years[28:],predictors)

# %%
mean_ap
# Out:
# 0.7430315431614715

# %% [markdown]
# By using a Random Forest Regressor, our model increased by 4%.

# %%
all_predictions[all_predictions["Rk"] < 6].sort_values("Diff").head(10)

# %%
all_predictions[all_predictions["Rk"] < 3].groupby("Rk").head(30)
# Out:
#                       Player  Share  predictions  Rk  Prediction_Rk  Diff  \
# 10261         David Robinson  0.508     0.159476   2              2     0
# 10962         Michael Jordan  0.986     0.140083   1              4    -3
# 1710             Karl Malone  0.857     0.171357   1              2    -1
# 10976         Michael Jordan  0.832     0.140057   2              3    -1
# 1723             Karl Malone  0.726     0.166212   2              2     0
# 10990         Michael Jordan  0.934     0.122499   1              4    -3
# 1736             Karl Malone  0.701     0.138245   1              2    -1
# 4931         Alonzo Mourning  0.655     0.088866   2              7    -5
# 143         Shaquille O'Neal  0.998     0.223928   1              1     0
# 5885           Kevin Garnett  0.337     0.097435   2              9    -7
# 9317              Tim Duncan  0.569     0.126003   2              3    -1
# 1030           Allen Iverson  0.904     0.104275   1              6    -5
# 5396              Tim Duncan  0.757     0.145827   1              2    -1
# 1334              Jason Kidd  0.712     0.044843   2             31   -29
# 12939             Tim Duncan  0.808     0.145407   1              3    -2
# 8892           Kevin Garnett  0.732     0.142847   2              4    -2
# 14388          Kevin Garnett  0.991     0.148135   1              2    -1
# 3984              Tim Duncan  0.582     0.142794   2              3    -1
# 4992        Shaquille O'Neal  0.813     0.163054   2              1     1
# 5420              Steve Nash  0.839     0.069339   1             15   -14
# 3434            LeBron James  0.550     0.166174   2              1     1
# 5438              Steve Nash  0.739     0.087746   1             11   -10
# 9937           Dirk Nowitzki  0.882     0.105112   1              4    -3
# 5453              Steve Nash  0.785     0.088614   2              8    -6
# 7010             Kobe Bryant  0.873     0.111469   1              4    -3
# 11958             Chris Paul  0.710     0.109791   2              5    -3
# 5787            LeBron James  0.969     0.178699   1              1     0
# 1829             Kobe Bryant  0.577     0.100836   2              5    -3
# 5804            LeBron James  0.980     0.193937   1              1     0
# 9229            Kevin Durant  0.495     0.109976   2              4    -2
# 12193          Dwight Howard  0.531     0.156953   2              1     1
# 12785           Derrick Rose  0.977     0.089629   1              8    -7
# 13627           LeBron James  0.888     0.168766   1              1     0
# 14018           Kevin Durant  0.735     0.136575   2              3    -1
# 13579           LeBron James  0.998     0.193380   1              1     0
# 14233           Kevin Durant  0.632     0.156777   2              2     0
# 6595            Kevin Durant  0.986     0.171905   1              1     0
# 13594           LeBron James  0.713     0.166514   2              2     0
# 13984           James Harden  0.720     0.127032   2              3    -1
# 6329           Stephen Curry  0.922     0.119329   1              4    -3
# 5824           Stephen Curry  1.000     0.165877   1              1     0
# 6548           Kawhi Leonard  0.484     0.094984   2             10    -8
# 11484           James Harden  0.746     0.175960   2              1     1
# 6647       Russell Westbrook  0.879     0.174165   1              2    -1
# 7895            LeBron James  0.731     0.174111   2              1     1
# 929             James Harden  0.955     0.174095   1              2    -1
# 11978  Giannis Antetokounmpo  0.932     0.196100   1              1     0
# 10065           James Harden  0.768     0.172746   2              2     0
# 12919  Giannis Antetokounmpo  0.952     0.226950   1              1     0
# 3912            LeBron James  0.746     0.145857   2              4    -2
# 9018             Joel Embiid  0.580     0.147280   2              2     0
# 641             Nikola Jokić  0.961     0.138867   1              3    -2
# 663             Nikola Jokić  0.875     0.195162   1              2    -1
# 837              Joel Embiid  0.706     0.177024   2              4    -2
#
#        Year   PTS   AST   TRB
# 10261  1996  25.0   3.0  12.2
# 10962  1996  30.4   4.3   6.6
# 1710   1997  27.4   4.5   9.9
# 10976  1997  29.6   4.3   5.9
# 1723   1998  27.0   3.9  10.3
# 10990  1998  28.7   3.5   5.8
# 1736   1999  23.8   4.1   9.4
# 4931   1999  20.1   1.6  11.0
# 143    2000  29.7   3.8  13.6
# 5885   2000  22.9   5.0  11.8
# 9317   2001  22.2   3.0  12.2
# 1030   2001  31.1   4.6   3.8
# 5396   2002  25.5   3.7  12.7
# 1334   2002  14.7   9.9   7.3
# 12939  2003  23.3   3.9  12.9
# 8892   2003  23.0   6.0  13.4
# 14388  2004  24.2   5.0  13.9
# 3984   2004  22.3   3.1  12.4
# 4992   2005  22.9   2.7  10.4
# 5420   2005  15.5  11.5   3.3
# 3434   2006  31.4   6.6   7.0
# 5438   2006  18.8  10.5   4.2
# 9937   2007  24.6   3.4   8.9
# 5453   2007  18.6  11.6   3.5
# 7010   2008  28.3   5.4   6.3
# 11958  2008  21.1  11.6   4.0
# 5787   2009  28.4   7.2   7.6
# 1829   2009  26.8   4.9   5.2
# 5804   2010  29.7   8.6   7.3
# 9229   2010  30.1   2.8   7.6
# 12193  2011  22.9   1.4  14.1
# 12785  2011  25.0   7.7   4.1
# 13627  2012  27.1   6.2   7.9
# 14018  2012  28.0   3.5   8.0
# 13579  2013  26.8   7.3   8.0
# 14233  2013  28.1   4.6   7.9
# 6595   2014  32.0   5.5   7.4
# 13594  2014  27.1   6.3   6.9
# 13984  2015  27.4   7.0   5.7
# 6329   2015  23.8   7.7   4.3
# 5824   2016  30.1   6.7   5.4
# 6548   2016  21.2   2.6   6.8
# 11484  2017  29.1  11.2   8.1
# 6647   2017  31.6  10.4  10.7
# 7895   2018  27.5   9.1   8.6
# 929    2018  30.4   8.8   5.4
# 11978  2019  27.7   5.9  12.5
# 10065  2019  36.1   7.5   6.6
# 12919  2020  29.5   5.6  13.6
# 3912   2020  25.3  10.2   7.8
# 9018   2021  28.5   2.8  10.6
# 641    2021  26.4   8.3  10.8
# 663    2022  27.1   7.9  13.8
# 837    2022  30.6   4.2  11.7

# %% [markdown]
# Here, I decided to play around with certain concepts in the MVP discussion. While this is not particularly true all the time, it is often specualted that the player with the best stats would receive the highest number of votes, as long as they have a winning team score. Therefore, I added more emphasis on PTS, AST, TRB, and eFG% columns by turning them into quadratic values to give these variables more weight in the model.

# %%
stats["PTS_2"] = stats["PTS"] * stats["PTS"]

# %%
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 14692   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 14693     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 14694  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 14695      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 14696      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#           AST_R     STL_R     BLK_R      3P_R    eFG%_R    W/L%_R     TRB_R  \
# 0      0.420714  0.961127  0.673469  0.508587  1.041653  1.438663  1.706296
# 1      1.028412  1.647646  0.673469  4.577279  1.093092  1.438663  0.812522
# 2      0.093492  0.274608  1.571429  0.000000  0.975210  1.438663  0.487513
# 3      0.186984  0.274608  0.000000  0.000000  0.728728  1.438663  0.325009
# 4      1.636110  1.784950  0.897959  1.525760  1.073803  1.438663  1.245867
# ...         ...       ...       ...       ...       ...       ...       ...
# 14692  0.819562  0.479763  1.528302  0.650951  1.074210  1.029491  0.981705
# 14693  0.000000  0.000000  0.000000  0.130190  0.724940  1.029491  0.112195
# 14694  0.601012  1.119447  2.547170  0.520761  0.992985  1.029491  1.598776
# 14695  0.218550  0.319842  1.273585  0.650951  1.088425  1.029491  0.560974
# 14696  0.655649  1.119447  0.509434  2.343424  1.194018  1.029491  0.869510
#
#        NPos  Ntm   PTS_2
# 0         2   15   82.81
# 1        12   15  210.25
# 2         2   15    7.84
# 3         2   15    3.24
# 4         8   15  457.96
# ...     ...  ...     ...
# 14692     2   18   38.44
# 14693     2   18    0.36
# 14694     2   18  116.64
# 14695     0   18   16.00
# 14696    12   18   72.25
#
# [14697 rows x 52 columns]

# %%
predictors += ["PTS_2"]

# %%
stats["AST_2"] = stats["AST"] * stats["AST"]
predictors += ["AST_2"]

# %%
stats["TRB_2"] = stats["TRB"] * stats["TRB"]
predictors += ["TRB_2"]

# %%
stats["eFG%_2"] = stats["eFG%"] * stats["eFG%"]
predictors += ["eFG%_2"]

# %%
mean_ap, aps, all_predictions = backtest(stats,reg,years[5:],predictors)

# %%
mean_ap
# Out:
# 0.725977351268948

# %%
all_predictions[all_predictions["Rk"] < 6].groupby("Rk").head(20)
# Out:
#                   Player  Share  predictions  Rk  Prediction_Rk  Diff  Year  \
# 10962     Michael Jordan  0.986     0.290991   1              1     0  1996
# 5197     Hakeem Olajuwon  0.211     0.264942   4              3     1  1996
# 10261     David Robinson  0.508     0.231424   2              4    -2  1996
# 7645   Anfernee Hardaway  0.319     0.097303   3             11    -8  1996
# 10965     Scottie Pippen  0.200     0.064252   5             18   -13  1996
# ...                  ...    ...          ...  ..            ...   ...   ...
# 6618   Russell Westbrook  0.271     0.194198   4              1     3  2015
# 4014        LeBron James  0.425     0.178484   3              2     1  2015
# 13984       James Harden  0.720     0.171407   2              3    -1  2015
# 4275       Anthony Davis  0.156     0.159507   5              4     1  2015
# 6329       Stephen Curry  0.922     0.140635   1              6    -5  2015
#
#         PTS  AST   TRB
# 10962  30.4  4.3   6.6
# 5197   26.9  3.6  10.9
# 10261  25.0  3.0  12.2
# 7645   21.7  7.1   4.3
# 10965  19.4  5.9   6.4
# ...     ...  ...   ...
# 6618   28.1  8.6   7.3
# 4014   25.3  7.4   6.0
# 13984  27.4  7.0   5.7
# 4275   24.4  2.2  10.2
# 6329   23.8  7.7   4.3
#
# [100 rows x 10 columns]

# %%
mean_ap, aps, all_predictions = backtest(stats,rf,years[28:],predictors)

# %%
mean_ap
# Out:
# 0.7381475257349244

# %%
all_predictions[all_predictions["Rk"] < 2].groupby("Rk").head(30)
# Out:
#                       Player  Share  predictions  Rk  Prediction_Rk  Diff  \
# 10962         Michael Jordan  0.986     0.246582   1              1     0
# 1710             Karl Malone  0.857     0.225376   1              3    -2
# 10990         Michael Jordan  0.934     0.209684   1              3    -2
# 1736             Karl Malone  0.701     0.148281   1              3    -2
# 143         Shaquille O'Neal  0.998     0.332874   1              1     0
# 1030           Allen Iverson  0.904     0.238466   1              2    -1
# 5396              Tim Duncan  0.757     0.179194   1              3    -2
# 12939             Tim Duncan  0.808     0.159596   1              6    -5
# 14388          Kevin Garnett  0.991     0.178313   1              1     0
# 5420              Steve Nash  0.839     0.081535   1             17   -16
# 5438              Steve Nash  0.739     0.098197   1             15   -14
# 9937           Dirk Nowitzki  0.882     0.123979   1              8    -7
# 7010             Kobe Bryant  0.873     0.179060   1              2    -1
# 5787            LeBron James  0.969     0.238417   1              2    -1
# 5804            LeBron James  0.980     0.281095   1              1     0
# 12785           Derrick Rose  0.977     0.131513   1              5    -4
# 13627           LeBron James  0.888     0.223789   1              1     0
# 13579           LeBron James  0.998     0.243591   1              1     0
# 6595            Kevin Durant  0.986     0.290738   1              1     0
# 6329           Stephen Curry  0.922     0.134189   1              5    -4
# 5824           Stephen Curry  1.000     0.259889   1              1     0
# 6647       Russell Westbrook  0.879     0.292139   1              1     0
# 929             James Harden  0.955     0.260426   1              1     0
# 11978  Giannis Antetokounmpo  0.932     0.237879   1              2    -1
# 12919  Giannis Antetokounmpo  0.952     0.295534   1              2    -1
# 641             Nikola Jokić  0.961     0.190838   1              5    -4
# 663             Nikola Jokić  0.875     0.249222   1              5    -4
#
#        Year   PTS   AST   TRB
# 10962  1996  30.4   4.3   6.6
# 1710   1997  27.4   4.5   9.9
# 10990  1998  28.7   3.5   5.8
# 1736   1999  23.8   4.1   9.4
# 143    2000  29.7   3.8  13.6
# 1030   2001  31.1   4.6   3.8
# 5396   2002  25.5   3.7  12.7
# 12939  2003  23.3   3.9  12.9
# 14388  2004  24.2   5.0  13.9
# 5420   2005  15.5  11.5   3.3
# 5438   2006  18.8  10.5   4.2
# 9937   2007  24.6   3.4   8.9
# 7010   2008  28.3   5.4   6.3
# 5787   2009  28.4   7.2   7.6
# 5804   2010  29.7   8.6   7.3
# 12785  2011  25.0   7.7   4.1
# 13627  2012  27.1   6.2   7.9
# 13579  2013  26.8   7.3   8.0
# 6595   2014  32.0   5.5   7.4
# 6329   2015  23.8   7.7   4.3
# 5824   2016  30.1   6.7   5.4
# 6647   2017  31.6  10.4  10.7
# 929    2018  30.4   8.8   5.4
# 11978  2019  27.7   5.9  12.5
# 12919  2020  29.5   5.6  13.6
# 641    2021  26.4   8.3  10.8
# 663    2022  27.1   7.9  13.8

# %% [markdown]
# While are Ridge regressor model improved, our Random Forest Model actually worsened. Therefore, the model with the highest precision is the model with the average ratios instead of the quadratic values.
#
# There are a lot more factors in determining the MVP vote of a player in a given season that can't be determined through stats, which is why models like these are very hard to predict, but getting a 74% accuracy, is still exceptional in determining something from nothing. Ideas like Voter Fatigue, where MVP voters will often get tired of voting for the same person every year even if they have the best stat line. If this weren't the case, then Lebron James, Stephen Curry, and Giannis Attentokunmpo would have a lot more MVPs under their belt. Another Idea is that MVP voters often like a story line when voting as well, players who little to no help from teamates in creating a winning team record while having the best stat line, or teams who improved their teams winning record by just joining the team earlier in the season often get brownie points that an algorithm can't necessarily predict.
#
# As I learn more about regression and machine learning, I will continue to build a model more and more accurate, so that one day I can have an algorithm for sports betting.
